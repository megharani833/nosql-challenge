# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
mongo.list_database_names()
# Out:
# ['admin',
#  'autosaurus',
#  'classDB',
#  'classDB_db',
#  'config',
#  'epa',
#  'fruits_db',
#  'garden_db',
#  'local',
#  'met',
#  'petsitly_marketing',
#  'travel_db',
#  'uk_food']

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query ={'scores.Hygiene': 20}

# Use count_documents to display the number of documents in the result

print(f" Number of documents in result: {establishments.count_documents(query)}")

# Display the first document in the results using pprint

results = establishments.find(query)

print('\n First Result:')
pprint(results[0])
# Out:
#  Number of documents in result: 41
#
#  First Result:
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6554169591c16743b302b517'),
#  'geocode': {'latitude': Decimal128('50.7697050000000'),
#              'longitude': Decimal128('0.276940000000000')},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/110681',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}

# %%
# Convert the result to a Pandas 

hygiene_df=pd.DataFrame(results)

# Display the number of rows in the DataFrame

print(f"Rows in DataFrame: {len(hygiene_df)}")

# Display the first 10 rows of the DataFrame

hygiene_df.head(10)
# Out:
# Rows in DataFrame: 41
#                         _id   FHRSID  ChangesByServerID  \
# 0  6554169591c16743b302b517   110681                  0
# 1  6554169691c16743b302b898   612039                  0
# 2  6554169691c16743b302bba1   730933                  0
# 3  6554169691c16743b302bd96   172735                  0
# 4  6554169691c16743b302bd9f   172953                  0
# 5  6554169691c16743b302c73e   512854                  0
# 6  6554169691c16743b302c95e  1537089                  0
# 7  6554169791c16743b302de8a   155648                  0
# 8  6554169891c16743b302e2cd  1012883                  0
# 9  6554169891c16743b302eae0   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# 4             PI/000024532              Golden Palace
# 5            12/00816/BUTH           Ashby's Butchers
# 6          22/00224/RESTUN  South Sea Express Cuisine
# 7              EH/00006058              Golden Palace
# 8         17/00110/MIXED/S             The Tulip Tree
# 9                    41811                      F & S
#
#                         BusinessType  BusinessTypeID           AddressLine1  \
# 0                    Caring Premises               5   5-6 Southfields Road
# 1                    Caring Premises               5              Hall Lane
# 2  Hotel/bed & breakfast/guest house            7842  53 Marine Parade East
# 3             Takeaway/sandwich shop            7844          4 High Street
# 4            Restaurant/Cafe/Canteen               1         5 South Street
# 5                  Retailers - other            4613   777 Southchurch Road
# 6            Restaurant/Cafe/Canteen               1    33 Alexandra Street
# 7             Takeaway/sandwich shop            7844          7 London Road
# 8            Restaurant/Cafe/Canteen               1          3 The Village
# 9                  Retailers - other            4613
#
#          AddressLine2 AddressLine3  ...  \
# 0          Eastbourne  East Sussex  ...
# 1  Walton-on-the-Naze        Essex  ...
# 2      Clacton On Sea        Essex  ...
# 3             Seaford  East Sussex  ...
# 4             Seaford  East Sussex  ...
# 5     Southend-On-Sea        Essex  ...
# 6     Southend-on-sea        Essex  ...
# 7            Rayleigh        Essex  ...
# 8       Chiddingstone         KENT  ...
# 9      81 Southernhay     Basildon  ...
#
#                       LocalAuthorityWebSite  \
# 0  http://www.eastbourne.gov.uk/foodratings
# 1             http://www.tendringdc.gov.uk/
# 2             http://www.tendringdc.gov.uk/
# 3       http://www.lewes-eastbourne.gov.uk/
# 4       http://www.lewes-eastbourne.gov.uk/
# 5                http://www.southend.gov.uk
# 6                http://www.southend.gov.uk
# 7                http://www.rochford.gov.uk
# 8              http://www.sevenoaks.gov.uk/
# 9                http://www.basildon.gov.uk
#
#               LocalAuthorityEmailAddress  \
# 0        Customerfirst@eastbourne.gov.uk
# 1             fhsadmin@tendringdc.gov.uk
# 2             fhsadmin@tendringdc.gov.uk
# 3    ehealth.ldc@lewes-eastbourne.gov.uk
# 4    ehealth.ldc@lewes-eastbourne.gov.uk
# 5    EnvironmentalHealth@southend.gov.uk
# 6    EnvironmentalHealth@southend.gov.uk
# 7       customerservices@rochford.gov.uk
# 8  environmental.health@sevenoaks.gov.uk
# 9                    ehs@basildon.gov.uk
#
#                                               scores  SchemeType  \
# 0  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
# 1  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...        FHRS
# 2  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
# 3  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...        FHRS
# 4  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...        FHRS
# 5  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
# 6  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
# 7  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...        FHRS
# 8  {'Hygiene': 20, 'Structural': 5, 'ConfidenceIn...        FHRS
# 9  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
#
#                                              geocode RightToReply  \
# 0  {'longitude': 0.276940000000000, 'latitude': 5...
# 1  {'longitude': 1.27872100000000, 'latitude': 51...
# 2  {'longitude': 1.15927000000000, 'latitude': 51...
# 3  {'longitude': 0.102020000000000, 'latitude': 5...
# 4  {'longitude': 0.101446000000000, 'latitude': 5...
# 5  {'longitude': 0.736349000000000, 'latitude': 5...
# 6  {'longitude': 0.712167100000000, 'latitude': 5...
# 7  {'longitude': 0.602364000000000, 'latitude': 5...
# 8  {'longitude': 0.146449998021126, 'latitude': 5...
# 9  {'longitude': 0.462307000000000, 'latitude': 5...
#
#       Distance NewRatingPending  \
# 0  4613.888288            False
# 1  4617.965824            False
# 2  4619.656144            False
# 3  4620.421725            False
# 4  4620.437179            False
# 5  4625.565258            False
# 6  4626.200132            False
# 7  4632.276890            False
# 8  4633.934041            False
# 9  4636.552523            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
# 1  [{'rel': 'self', 'href': 'https://api.ratings....
# 2  [{'rel': 'self', 'href': 'https://api.ratings....
# 3  [{'rel': 'self', 'href': 'https://api.ratings....
# 4  [{'rel': 'self', 'href': 'https://api.ratings....
# 5  [{'rel': 'self', 'href': 'https://api.ratings....
# 6  [{'rel': 'self', 'href': 'https://api.ratings....
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [10 rows x 28 columns]

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query2 = {'LocalAuthorityName': {'$regex': 'London'}, 'RatingValue': {'$gte': 4}}

# Use count_documents to display the number of documents in the result
print(f" Number of documents in result: {establishments.count_documents(query2)}")

# Display the first document in the results using pprint
results = establishments.find(query2)

print('\n First Result:')
pprint(results[0])
# Out:
#  Number of documents in result: 33
#
#  First Result:
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6554169791c16743b302cf31'),
#  'geocode': {'latitude': Decimal128('51.3693210000000'),
#              'longitude': Decimal128('0.508551000000000')},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/621707',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 10}}

# %%
# Convert the result to a Pandas DataFrame

london_df = pd.DataFrame(results)
# Display the number of rows in the DataFrame

print(f"Rows in DataFrame: {len(london_df)}")

# Display the first 10 rows of the DataFrame

london_df.head(10)
# Out:
# Rows in DataFrame: 33
#                         _id   FHRSID  ChangesByServerID  \
# 0  6554169791c16743b302cf31   621707                  0
# 1  6554169791c16743b302d25e  1130836                  0
# 2  6554169791c16743b302dda5   293783                  0
# 3  6554169891c16743b302eba4  1315095                  0
# 4  6554169891c16743b302eba6   294474                  0
# 5  6554169891c16743b302f2ac   294900                  0
# 6  6554169a91c16743b30313c2   293756                  0
# 7  6554169a91c16743b3031783   878523                  0
# 8  6554169a91c16743b303179d   293772                  0
# 9  6554169a91c16743b303179e   294606                  0
#
#   LocalAuthorityBusinessID                          BusinessName  \
# 0             PI/000025307                             Charlie's
# 1             PI/000034075               Mv City Cruises Erasmus
# 2             PI/000002614             Benfleet Motor Yacht Club
# 3             PI/000036464  Coombs Catering t/a The Lock and Key
# 4             PI/000014647              Tilbury Seafarers Centre
# 5             PI/000019066                            Mv Valulla
# 6             PI/000002538                         Tereza Joanne
# 7             PI/000029844                      Brick Lane Brews
# 8             PI/000002585         The Nuance Group (UK) Limited
# 9             PI/000016185                              WH Smith
#
#               BusinessType  BusinessTypeID  \
# 0  Other catering premises            7841
# 1  Other catering premises            7841
# 2  Other catering premises            7841
# 3  Restaurant/Cafe/Canteen               1
# 4  Restaurant/Cafe/Canteen               1
# 5  Other catering premises            7841
# 6  Other catering premises            7841
# 7  Restaurant/Cafe/Canteen               1
# 8        Retailers - other            4613
# 9        Retailers - other            4613
#
#                                         AddressLine1  \
# 0         Oak Apple Farm Building 103 Sheernes Docks
# 1                                 Cherry Garden Pier
# 2                                         Ferry Road
# 3                                  Leslie Ford House
# 4                          Tenants Row Tilbury Docks
# 5  Reeds River Cruises LtdKings ReachRiver Thames...
# 6  Funcraft UK Ltd King George V Dock Woolwich Ma...
# 7                       Air side London City Airport
# 8                  Duty Free Shop Passenger Terminal
# 9                                London City Airport
#
#                            AddressLine2 AddressLine3  ...  \
# 0                           Sheppy Kent               ...
# 1      Cherry Garden Street Rotherhithe     Charlton  ...
# 2                  South Benfleet Essex               ...
# 3                               Tilbury     Charlton  ...
# 4                         Tilbury Essex               ...
# 5                                London               ...
# 6                                London               ...
# 7                                London               ...
# 8  London City AirportRoyal DocksLondon               ...
# 9                     Silvertown London               ...
#
#                                LocalAuthorityWebSite  \
# 0  http://www.cityoflondon.gov.uk/Corporation/hom...
# 1  http://www.cityoflondon.gov.uk/Corporation/hom...
# 2  http://www.cityoflondon.gov.uk/Corporation/hom...
# 3  http://www.cityoflondon.gov.uk/Corporation/hom...
# 4  http://www.cityoflondon.gov.uk/Corporation/hom...
# 5  http://www.cityoflondon.gov.uk/Corporation/hom...
# 6  http://www.cityoflondon.gov.uk/Corporation/hom...
# 7  http://www.cityoflondon.gov.uk/Corporation/hom...
# 8  http://www.cityoflondon.gov.uk/Corporation/hom...
# 9  http://www.cityoflondon.gov.uk/Corporation/hom...
#
#              LocalAuthorityEmailAddress  \
# 0  publicprotection@cityoflondon.gov.uk
# 1  publicprotection@cityoflondon.gov.uk
# 2  publicprotection@cityoflondon.gov.uk
# 3  publicprotection@cityoflondon.gov.uk
# 4  publicprotection@cityoflondon.gov.uk
# 5  publicprotection@cityoflondon.gov.uk
# 6  publicprotection@cityoflondon.gov.uk
# 7  publicprotection@cityoflondon.gov.uk
# 8  publicprotection@cityoflondon.gov.uk
# 9  publicprotection@cityoflondon.gov.uk
#
#                                               scores  SchemeType  \
# 0  {'Hygiene': 5, 'Structural': 10, 'ConfidenceIn...        FHRS
# 1  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 2  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 3  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 4  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 5  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 6  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 7  {'Hygiene': 10, 'Structural': 5, 'ConfidenceIn...        FHRS
# 8  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 9  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
#
#                                              geocode RightToReply  \
# 0  {'longitude': 0.508551000000000, 'latitude': 5...
# 1  {'longitude': 0.249255999922752, 'latitude': 5...
# 2  {'longitude': 0.561954000000000, 'latitude': 5...
# 3  {'longitude': 0.346336990594864, 'latitude': 5...
# 4  {'longitude': 0.346325000000000, 'latitude': 5...
# 5  {'longitude': 0.287555000000000, 'latitude': 5...
# 6  {'longitude': 0.0692860000000000, 'latitude': ...
# 7  {'longitude': 0.0480060000000000, 'latitude': ...
# 8  {'longitude': 0.0479660000000000, 'latitude': ...
# 9  {'longitude': 0.0479655750095844, 'latitude': ...
#
#       Distance NewRatingPending  \
# 0  4627.439468            False
# 1  4627.873179            False
# 2  4631.968418            False
# 3  4636.846754            False
# 4  4636.847650            False
# 5  4640.460834            False
# 6  4648.301822            False
# 7  4649.173485            False
# 8  4649.188826            False
# 9  4649.188850            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
# 1  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 2  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 3  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 4  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 5  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 6  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [10 rows x 28 columns]

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score


# Change the data type from String to Decimal for latitude
lat_type = establishments.update_many({}, [
                                                {'$set':
                                                        {"geocode.latitude":
                                                            {'$toDecimal': "$geocode.latitude"}
                                                        }
                                                }
                                            ]
                                      )

# Change the data type from String to Decimal for longitude
long_type = establishments.update_many({}, [
                                                {'$set':
                                                        {"geocode.longitude":
                                                            {'$toDecimal': "$geocode.longitude"}
                                                        }
                                                }
                                            ]
                                      )

degree_search = 0.01
latitude = 51.49014200
longitude = 0.08384000

query = query3 = {'geocode.latitude': {'$gte': latitude - degree_search, '$lte': latitude + degree_search}, 
         'geocode.longitude': {'$gte': longitude - degree_search, '$lte': longitude + degree_search},
         'RatingValue': 4
        }

# Sort by hygiene score
sort = [('scores.Hygiene', -1)] 
# Limit to top 5 establoshments
limit = 5

# Print the results
pprint(list(establishments.find(query3).sort(sort)))
# Out:
# [{'AddressLine1': 'Unit 15 71 - 73 Nathan Way',
#   'AddressLine2': '',
#   'AddressLine3': 'Thamesmead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'john and biola foods',
#   'BusinessType': 'Retailers - other',
#   'BusinessTypeID': 4613,
#   'ChangesByServerID': 0,
#   'Distance': 4647.128625734506,
#   'FHRSID': 1357499,
#   'LocalAuthorityBusinessID': '14244',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE28 0BQ',
#   'RatingDate': '2021-06-02T00:00:00',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingValue': 4,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('6554169a91c16743b3030edb'),
#   'geocode': {'latitude': Decimal128('51.4926166000000'),
#               'longitude': Decimal128('0.0929122000000000')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1357499',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 10, 'Structural': 10}},
#  {'AddressLine1': 'The Ship 205 Plumstead Common Road',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'The Ship',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'ChangesByServerID': 0,
#   'Distance': 4647.169432009829,
#   'FHRSID': 694597,
#   'LocalAuthorityBusinessID': 'PI/000116267',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 2UJ',
#   'RatingDate': '2022-06-28T00:00:00',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingValue': 4,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('6554169a91c16743b3030f2b'),
#   'geocode': {'latitude': Decimal128('51.4810979000000'),
#               'longitude': Decimal128('0.0802144000000000')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/694597',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 10, 'Structural': 0}},
#  {'AddressLine1': '2B Brewery Road',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Delicious Fried Chicken',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'ChangesByServerID': 0,
#   'Distance': 4647.330799112599,
#   'FHRSID': 694129,
#   'LocalAuthorityBusinessID': 'PI/000020415',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 7PT',
#   'RatingDate': '2021-05-12T00:00:00',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingValue': 4,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('6554169a91c16743b3030fd0'),
#   'geocode': {'latitude': Decimal128('51.4859196000000'),
#               'longitude': Decimal128('0.0806355000000000')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/694129',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 10, 'Structural': 5}},
#  {'AddressLine1': '151 Plumstead Road',
#   'AddressLine2': '',
#   'AddressLine3': 'Woolwich',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Expo International Supermarket',
#   'BusinessType': 'Retailers - other',
#   'BusinessTypeID': 4613,
#   'ChangesByServerID': 0,
#   'Distance': 4647.3531568734425,
#   'FHRSID': 906215,
#   'LocalAuthorityBusinessID': 'PI/000200956',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 7DY',
#   'RatingDate': '2019-08-15T00:00:00',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingValue': 4,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('6554169a91c16743b3030ff2'),
#   'geocode': {'latitude': Decimal128('51.4900564000000'),
#               'longitude': Decimal128('0.0841804000000000')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/906215',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 10, 'Structural': 5}},
#  {'AddressLine1': '1 Brewery Road',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'The Frying Pan 2',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'ChangesByServerID': 0,
#   'Distance': 4647.367450550816,
#   'FHRSID': 747148,
#   'LocalAuthorityBusinessID': 'PI/000188195',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 7PS',
#   'RatingDate': '2021-07-21T00:00:00',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingValue': 4,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('6554169a91c16743b3030fff'),
#   'geocode': {'latitude': Decimal128('51.4862464000000'),
#               'longitude': Decimal128('0.0799590000000000')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/747148',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 10, 'Structural': 5}},
#  {'AddressLine1': '119 Plumstead High Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Ho Wah Chinese Takeaway',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'ChangesByServerID': 0,
#   'Distance': 4646.980788747604,
#   'FHRSID': 1415716,
#   'LocalAuthorityBusinessID': '14784',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1SE',
#   'RatingDate': '2021-10-05T00:00:00',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingValue': 4,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('6554169a91c16743b3030da9'),
#   'geocode': {'latitude': Decimal128('51.4876867000000'),
#               'longitude': Decimal128('0.0920093000000000')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1415716',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 10, 'Hygiene': 5, 'Structural': 5}},
#  {'AddressLine1': '27 - 29 Lakedale Road',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'London Grocery Store',
#   'BusinessType': 'Retailers - other',
#   'BusinessTypeID': 4613,
#   'ChangesByServerID': 0,
#   'Distance': 4646.980869496588,
#   'FHRSID': 1369377,
#   'LocalAuthorityBusinessID': '14345',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1PP',
#   'RatingDate': '2022-02-17T00:00:00',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingValue': 4,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('6554169a91c16743b3030daa'),
#   'geocode': {'latitude': Decimal128('51.4870072000000'),
#               'longitude': Decimal128('0.0913239000000000')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1369377',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 10, 'Hygiene': 5, 'Structural': 5}},
#  {'AddressLine1': '52 Plumstead High Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Sushi Kitchen & Pizzeria Italiana',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'ChangesByServerID': 0,
#   'Distance': 4647.152087398501,
#   'FHRSID': 843827,
#   'LocalAuthorityBusinessID': 'PI/000199271',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1SL',
#   'RatingDate': '2021-10-20T00:00:00',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingValue': 4,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('6554169a91c16743b3030f03'),
#   'geocode': {'latitude': Decimal128('51.4886789000000'),
#               'longitude': Decimal128('0.0883094000000000')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/843827',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 5, 'Structural': 10}},
#  {'AddressLine1': '48 Plumstead High Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'New Royal China',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'ChangesByServerID': 0,
#   'Distance': 4647.160162948715,
#   'FHRSID': 1096704,
#   'LocalAuthorityBusinessID': '12326',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1SL',
#   'RatingDate': '2021-08-23T00:00:00',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingValue': 4,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('6554169a91c16743b3030f15'),
#   'geocode': {'latitude': Decimal128('51.4887446000000'),
#               'longitude': Decimal128('0.0881540000000000')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1096704',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 10}},
#  {'AddressLine1': '24 Conway Road',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Tasty Chicken',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'ChangesByServerID': 0,
#   'Distance': 4647.171729987437,
#   'FHRSID': 847090,
#   'LocalAuthorityBusinessID': 'PI/000199457',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1AH',
#   'RatingDate': '2020-10-28T00:00:00',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingValue': 4,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('6554169a91c16743b3030f2a'),
#   'geocode': {'latitude': Decimal128('51.4870186000000'),
#               'longitude': Decimal128('0.0861017000000000')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/847090',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 5, 'Structural': 10}},
#  {'AddressLine1': '7A Plumstead High Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Adam Meats',
#   'BusinessType': 'Retailers - other',
#   'BusinessTypeID': 4613,
#   'ChangesByServerID': 0,
#   'Distance': 4647.246139935266,
#   'FHRSID': 1170962,
#   'LocalAuthorityBusinessID': 'PI/000117309',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1SA',
#   'RatingDate': '2021-04-22T00:00:00',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingValue': 4,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('6554169a91c16743b3030f73'),
#   'geocode': {'latitude': Decimal128('51.4894485473633'),
#               'longitude': Decimal128('0.0865039974451065')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1170962',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 10}},
#  {'AddressLine1': 'South Rise Primary School Brewery Road',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'South Rise Primary School',
#   'BusinessType': 'School/college/university',
#   'BusinessTypeID': 7845,
#   'ChangesByServerID': 0,
#   'Distance': 4647.324698220066,
#   'FHRSID': 1257205,
#   'LocalAuthorityBusinessID': '13545',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 7PX',
#   'RatingDate': '2021-03-16T00:00:00',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingValue': 4,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('6554169a91c16743b3030fc4'),
#   'geocode': {'latitude': Decimal128('51.4862442016602'),
#               'longitude': Decimal128('0.0811289995908737')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1257205',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 5, 'Structural': 10}},
#  {'AddressLine1': '226 Elmley Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Emmaus Greenwich',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'ChangesByServerID': 0,
#   'Distance': 4647.333877442157,
#   'FHRSID': 694266,
#   'LocalAuthorityBusinessID': 'PI/000051400',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 7NL',
#   'RatingDate': '2021-05-12T00:00:00',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingValue': 4,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('6554169a91c16743b3030fd5'),
#   'geocode': {'latitude': Decimal128('51.4874229431152'),
#               'longitude': Decimal128('0.0820619985461235')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/694266',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 10, 'Hygiene': 5, 'Structural': 5}},
#  {'AddressLine1': '154 Plumstead Road',
#   'AddressLine2': '',
#   'AddressLine3': 'Woolwich',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'AK Grills',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'ChangesByServerID': 0,
#   'Distance': 4647.347385066153,
#   'FHRSID': 695536,
#   'LocalAuthorityBusinessID': 'PI/000188194',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 7DY',
#   'RatingDate': '2021-03-09T00:00:00',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingValue': 4,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('6554169a91c16743b3030fea'),
#   'geocode': {'latitude': Decimal128('51.4900609000000'),
#               'longitude': Decimal128('0.0843432000000000')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/695536',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 5, 'Structural': 10}},
#  {'AddressLine1': '13 Brewery Road',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Premier Fruit and Veg Ltd',
#   'BusinessType': 'Retailers - other',
#   'BusinessTypeID': 4613,
#   'ChangesByServerID': 0,
#   'Distance': 4647.350256722869,
#   'FHRSID': 850356,
#   'LocalAuthorityBusinessID': 'PI/000199672',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 7PS',
#   'RatingDate': '2021-10-07T00:00:00',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingValue': 4,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('6554169a91c16743b3030fec'),
#   'geocode': {'latitude': Decimal128('51.4862205000000'),
#               'longitude': Decimal128('0.0804044000000000')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/850356',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 10, 'Hygiene': 5, 'Structural': 5}},
#  {'AddressLine1': '141 Plumstead Road',
#   'AddressLine2': '',
#   'AddressLine3': 'Woolwich',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Plumstead Food & Wine',
#   'BusinessType': 'Retailers - other',
#   'BusinessTypeID': 4613,
#   'ChangesByServerID': 0,
#   'Distance': 4647.384870484812,
#   'FHRSID': 694634,
#   'LocalAuthorityBusinessID': 'PI/000117468',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 7DY',
#   'RatingDate': '2022-05-24T00:00:00',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingValue': 4,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('6554169a91c16743b3031009'),
#   'geocode': {'latitude': Decimal128('51.4902011000000'),
#               'longitude': Decimal128('0.0834562000000000')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/694634',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 10, 'Hygiene': 5, 'Structural': 5}},
#  {'AddressLine1': '136 Plumstead High Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Angels Bakery',
#   'BusinessType': 'Manufacturers/packers',
#   'BusinessTypeID': 7839,
#   'ChangesByServerID': 0,
#   'Distance': 4646.958690760583,
#   'FHRSID': 695079,
#   'LocalAuthorityBusinessID': 'PI/000175160',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1JQ',
#   'RatingDate': '2021-08-31T00:00:00',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingValue': 4,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('6554169a91c16743b3030d6a'),
#   'geocode': {'latitude': Decimal128('51.4873404000000'),
#               'longitude': Decimal128('0.0922671000000000')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/695079',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 10, 'Hygiene': 0, 'Structural': 10}},
#  {'AddressLine1': '45 Lakedale Road',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'The Gurkha Club',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'ChangesByServerID': 0,
#   'Distance': 4646.972943670141,
#   'FHRSID': 741736,
#   'LocalAuthorityBusinessID': 'PI/000177071',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1PR',
#   'RatingDate': '2020-08-05T00:00:00',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingValue': 4,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('6554169a91c16743b3030d8e'),
#   'geocode': {'latitude': Decimal128('51.4865168000000'),
#               'longitude': Decimal128('0.0910482000000000')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/741736',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 10, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': '23 Lakedale Road',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'BakeYard',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'ChangesByServerID': 0,
#   'Distance': 4646.985554624728,
#   'FHRSID': 1497299,
#   'LocalAuthorityBusinessID': '15139',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1PP',
#   'RatingDate': '2022-07-28T00:00:00',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingValue': 4,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('6554169a91c16743b3030daf'),
#   'geocode': {'latitude': Decimal128('51.4871324000000'),
#               'longitude': Decimal128('0.0913213000000000')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1497299',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 10, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': '107 Plumstead High Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'EVER FRESH INDIAN STREET FOOD',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'ChangesByServerID': 0,
#   'Distance': 4646.999553676595,
#   'FHRSID': 1489061,
#   'LocalAuthorityBusinessID': '15079',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1SE',
#   'RatingDate': '2022-06-29T00:00:00',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingValue': 4,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('6554169a91c16743b3030ddb'),
#   'geocode': {'latitude': Decimal128('51.4877576000000'),
#               'longitude': Decimal128('0.0915660000000000')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1489061',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 10, 'Hygiene': 0, 'Structural': 10}},
#  {'AddressLine1': '98A Plumstead High Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Milsha Stores',
#   'BusinessType': 'Retailers - other',
#   'BusinessTypeID': 4613,
#   'ChangesByServerID': 0,
#   'Distance': 4647.079164412819,
#   'FHRSID': 695423,
#   'LocalAuthorityBusinessID': 'PI/000185605',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1SL',
#   'RatingDate': '2022-07-30T00:00:00',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingValue': 4,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('6554169a91c16743b3030e76'),
#   'geocode': {'latitude': Decimal128('51.4880962000000'),
#               'longitude': Decimal128('0.0897233000000000')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/695423',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 10}},
#  {'AddressLine1': 'Shop And Premises Rear Of 105 Plumstead High Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Punjabi Dhaba',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'ChangesByServerID': 0,
#   'Distance': 4647.082395455037,
#   'FHRSID': 695307,
#   'LocalAuthorityBusinessID': 'PI/000182603',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1SB',
#   'RatingDate': '2021-07-14T00:00:00',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingValue': 4,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('6554169a91c16743b3030e87'),
#   'geocode': {'latitude': Decimal128('51.4884605407715'),
#               'longitude': Decimal128('0.0900010019540787')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/695307',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 10, 'Hygiene': 0, 'Structural': 10}},
#  {'AddressLine1': 'Red Lion 95 Plumstead High Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Red Lion Noodle Bar / Red Lion Sushi Bar',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'ChangesByServerID': 0,
#   'Distance': 4647.085827733093,
#   'FHRSID': 710379,
#   'LocalAuthorityBusinessID': 'PI/000172941',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1SB',
#   'RatingDate': '2021-10-12T00:00:00',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingValue': 4,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('6554169a91c16743b3030e8c'),
#   'geocode': {'latitude': Decimal128('51.4883651733398'),
#               'longitude': Decimal128('0.0898109972476959')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/710379',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 10, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': '86 Plumstead High Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Kebabish',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'ChangesByServerID': 0,
#   'Distance': 4647.096608614254,
#   'FHRSID': 850355,
#   'LocalAuthorityBusinessID': 'PI/000199611',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1SL',
#   'RatingDate': '2020-11-04T00:00:00',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingValue': 4,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('6554169a91c16743b3030eae'),
#   'geocode': {'latitude': Decimal128('51.4882194000000'),
#               'longitude': Decimal128('0.0893688000000000')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/850355',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 10}},
#  {'AddressLine1': '28 Conway Road',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Astra Food & Wine',
#   'BusinessType': 'Retailers - other',
#   'BusinessTypeID': 4613,
#   'ChangesByServerID': 0,
#   'Distance': 4647.164845364151,
#   'FHRSID': 694216,
#   'LocalAuthorityBusinessID': 'PI/000036431',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1AH',
#   'RatingDate': '2020-02-13T00:00:00',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingValue': 4,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('6554169a91c16743b3030f23'),
#   'geocode': {'latitude': Decimal128('51.4869647000000'),
#               'longitude': Decimal128('0.0862363000000000')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/694216',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 10, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': '187A Plumstead Common Road',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Pizza Time',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'ChangesByServerID': 0,
#   'Distance': 4647.19252650455,
#   'FHRSID': 1344409,
#   'LocalAuthorityBusinessID': '14174',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 2UJ',
#   'RatingDate': '2021-11-03T00:00:00',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingValue': 4,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('6554169a91c16743b3030f42'),
#   'geocode': {'latitude': Decimal128('51.4810623000000'),
#               'longitude': Decimal128('0.0795455000000000')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1344409',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 10, 'Hygiene': 0, 'Structural': 10}},
#  {'AddressLine1': '152 Plumstead Common Road',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Cheers',
#   'BusinessType': 'Retailers - other',
#   'BusinessTypeID': 4613,
#   'ChangesByServerID': 0,
#   'Distance': 4647.2192435375,
#   'FHRSID': 694591,
#   'LocalAuthorityBusinessID': 'PI/000116182',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 2UL',
#   'RatingDate': '2019-11-04T00:00:00',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingValue': 4,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('6554169a91c16743b3030f55'),
#   'geocode': {'latitude': Decimal128('51.4807948000000'),
#               'longitude': Decimal128('0.0785443000000000')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/694591',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 10, 'Hygiene': 0, 'Structural': 10}},
#  {'AddressLine1': '142 Plumstead Common Road',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Lucky Food and Wine',
#   'BusinessType': 'Retailers - other',
#   'BusinessTypeID': 4613,
#   'ChangesByServerID': 0,
#   'Distance': 4647.224660225594,
#   'FHRSID': 1427472,
#   'LocalAuthorityBusinessID': '14868',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 2UL',
#   'RatingDate': '2021-12-09T00:00:00',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingValue': 4,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('6554169a91c16743b3030f62'),
#   'geocode': {'latitude': Decimal128('51.4807723000000'),
#               'longitude': Decimal128('0.0783732000000000')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1427472',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 10, 'Hygiene': 0, 'Structural': 10}},
#  {'AddressLine1': '121 Plumstead Common Road',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Costcutter',
#   'BusinessType': 'Retailers - other',
#   'BusinessTypeID': 4613,
#   'ChangesByServerID': 0,
#   'Distance': 4647.259049794602,
#   'FHRSID': 776414,
#   'LocalAuthorityBusinessID': 'PI/000197886',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 2UQ',
#   'RatingDate': '2020-11-24T00:00:00',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingValue': 4,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('6554169a91c16743b3030f8c'),
#   'geocode': {'latitude': Decimal128('51.4811859130859'),
#               'longitude': Decimal128('0.0778459981083870')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/776414',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 10}},
#  {'AddressLine1': '10 Plumstead High Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': "Morley's",
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'ChangesByServerID': 0,
#   'Distance': 4647.259298536813,
#   'FHRSID': 810996,
#   'LocalAuthorityBusinessID': 'PI/000198690',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1SN',
#   'RatingDate': '2020-07-06T00:00:00',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingValue': 4,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('6554169a91c16743b3030f8e'),
#   'geocode': {'latitude': Decimal128('51.4892958000000'),
#               'longitude': Decimal128('0.0859896000000000')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/810996',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 10, 'Hygiene': 0, 'Structural': 5}},
#  {'AddressLine1': '158 Plumstead Road',
#   'AddressLine2': '',
#   'AddressLine3': 'Woolwich',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Fusion',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'ChangesByServerID': 0,
#   'Distance': 4647.334203006979,
#   'FHRSID': 1357497,
#   'LocalAuthorityBusinessID': '14242',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 7DY',
#   'RatingDate': '2021-10-14T00:00:00',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingValue': 4,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('6554169a91c16743b3030fd7'),
#   'geocode': {'latitude': Decimal128('51.4899501000000'),
#               'longitude': Decimal128('0.0845933000000000')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1357497',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 10}},
#  {'AddressLine1': '25 Waverley Road',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Corner Cafe',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'ChangesByServerID': 0,
#   'Distance': 4647.350619440211,
#   'FHRSID': 694849,
#   'LocalAuthorityBusinessID': 'PI/000155370',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 7TL',
#   'RatingDate': '2020-08-10T00:00:00',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingValue': 4,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('6554169a91c16743b3030fee'),
#   'geocode': {'latitude': Decimal128('51.4859680000000'),
#               'longitude': Decimal128('0.0801407000000000')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/694849',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 10}},
#  {'AddressLine1': '9 Brewery Road',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Santhiya Convenient Store',
#   'BusinessType': 'Retailers - other',
#   'BusinessTypeID': 4613,
#   'ChangesByServerID': 0,
#   'Distance': 4647.3588064361675,
#   'FHRSID': 695354,
#   'LocalAuthorityBusinessID': 'PI/000183586',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 7PS',
#   'RatingDate': '2019-10-15T00:00:00',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingValue': 4,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('6554169a91c16743b3030ff9'),
#   'geocode': {'latitude': Decimal128('51.4862246000000'),
#               'longitude': Decimal128('0.0801741000000000')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/695354',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 10}},
#  {'AddressLine1': '138 Plumstead Road',
#   'AddressLine2': '',
#   'AddressLine3': 'Woolwich',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Village Fresh Naan Ltd',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'ChangesByServerID': 0,
#   'Distance': 4647.3941440285835,
#   'FHRSID': 1104729,
#   'LocalAuthorityBusinessID': '12441',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 7DY',
#   'RatingDate': '2021-03-03T00:00:00',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingValue': 4,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('6554169a91c16743b3031012'),
#   'geocode': {'latitude': Decimal128('51.4902969000000'),
#               'longitude': Decimal128('0.0832982000000000')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1104729',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 10, 'Hygiene': 0, 'Structural': 10}},
#  {'AddressLine1': '1 Sandbach Place',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Foxfield Primary School',
#   'BusinessType': 'School/college/university',
#   'BusinessTypeID': 7845,
#   'ChangesByServerID': 0,
#   'Distance': 4647.546411791062,
#   'FHRSID': 1178816,
#   'LocalAuthorityBusinessID': '13003',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 7EX',
#   'RatingDate': '2021-09-30T00:00:00',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingValue': 4,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('6554169a91c16743b3031096'),
#   'geocode': {'latitude': Decimal128('51.4869768000000'),
#               'longitude': Decimal128('0.0757862000000000')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1178816',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 10}},
#  {'AddressLine1': '3 Whinchat Road',
#   'AddressLine2': '',
#   'AddressLine3': 'Thamesmead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Dynamic Off Licence',
#   'BusinessType': 'Retailers - other',
#   'BusinessTypeID': 4613,
#   'ChangesByServerID': 0,
#   'Distance': 4647.549595459716,
#   'FHRSID': 695582,
#   'LocalAuthorityBusinessID': 'PI/000188878',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE28 0DZ',
#   'RatingDate': '2022-02-17T00:00:00',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingValue': 4,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('6554169a91c16743b3031099'),
#   'geocode': {'latitude': Decimal128('51.4940451000000'),
#               'longitude': Decimal128('0.0828032000000000')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/695582',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 10, 'Hygiene': 0, 'Structural': 10}},
#  {'AddressLine1': 'Cafe 9 - 11 Gunnery Terrace Cornwallis Road',
#   'AddressLine2': '',
#   'AddressLine3': 'Woolwich',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'TJ Enterprises Foodz Ltd',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'ChangesByServerID': 0,
#   'Distance': 4647.804565120756,
#   'FHRSID': 1226527,
#   'LocalAuthorityBusinessID': '13340',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 6SW',
#   'RatingDate': '2020-07-14T00:00:00',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingValue': 4,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('6554169a91c16743b30311c2'),
#   'geocode': {'latitude': Decimal128('51.4922421000000'),
#               'longitude': Decimal128('0.0739989000000000')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1226527',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 10, 'Hygiene': 0, 'Structural': 5}}]

# %%
# Run the query as a list and save the results to a variable
results3 = list(establishments.find(query3).sort(sort).limit(limit))

# Convert result to Pandas DataFrame

query3_df = pd.DataFrame(results3)

# Display the number of rows in the DataFrame
print("Rows in DataFrame: ", len(query3_df))

# Display the first 10 rows of the DataFrame
query3_df.head(10)
# Out:
# Rows in DataFrame:  5
#                         _id   FHRSID  ChangesByServerID  \
# 0  6554169a91c16743b3030fd0   694129                  0
# 1  6554169a91c16743b3030edb  1357499                  0
# 2  6554169a91c16743b3030fff   747148                  0
# 3  6554169a91c16743b3030ff2   906215                  0
# 4  6554169a91c16743b3030f2b   694597                  0
#
#   LocalAuthorityBusinessID                    BusinessName  \
# 0             PI/000020415         Delicious Fried Chicken
# 1                    14244            john and biola foods
# 2             PI/000188195                The Frying Pan 2
# 3             PI/000200956  Expo International Supermarket
# 4             PI/000116267                        The Ship
#
#              BusinessType  BusinessTypeID                        AddressLine1  \
# 0  Takeaway/sandwich shop            7844                     2B Brewery Road
# 1       Retailers - other            4613          Unit 15 71 - 73 Nathan Way
# 2  Takeaway/sandwich shop            7844                      1 Brewery Road
# 3       Retailers - other            4613                  151 Plumstead Road
# 4       Pub/bar/nightclub            7843  The Ship 205 Plumstead Common Road
#
#   AddressLine2 AddressLine3  ...             LocalAuthorityWebSite  \
# 0                 Plumstead  ...  http://www.royalgreenwich.gov.uk
# 1                Thamesmead  ...  http://www.royalgreenwich.gov.uk
# 2                 Plumstead  ...  http://www.royalgreenwich.gov.uk
# 3                  Woolwich  ...  http://www.royalgreenwich.gov.uk
# 4                 Plumstead  ...  http://www.royalgreenwich.gov.uk
#
#      LocalAuthorityEmailAddress  \
# 0  health@royalgreenwich.gov.uk
# 1  health@royalgreenwich.gov.uk
# 2  health@royalgreenwich.gov.uk
# 3  health@royalgreenwich.gov.uk
# 4  health@royalgreenwich.gov.uk
#
#                                               scores  SchemeType  \
# 0  {'Hygiene': 10, 'Structural': 5, 'ConfidenceIn...        FHRS
# 1  {'Hygiene': 10, 'Structural': 10, 'ConfidenceI...        FHRS
# 2  {'Hygiene': 10, 'Structural': 5, 'ConfidenceIn...        FHRS
# 3  {'Hygiene': 10, 'Structural': 5, 'ConfidenceIn...        FHRS
# 4  {'Hygiene': 10, 'Structural': 0, 'ConfidenceIn...        FHRS
#
#                                              geocode RightToReply  \
# 0  {'longitude': 0.0806355000000000, 'latitude': ...
# 1  {'longitude': 0.0929122000000000, 'latitude': ...
# 2  {'longitude': 0.0799590000000000, 'latitude': ...
# 3  {'longitude': 0.0841804000000000, 'latitude': ...
# 4  {'longitude': 0.0802144000000000, 'latitude': ...
#
#       Distance NewRatingPending  \
# 0  4647.330799            False
# 1  4647.128626            False
# 2  4647.367451            False
# 3  4647.353157            False
# 4  4647.169432            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 1  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 2  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 3  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 4  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [5 rows x 28 columns]

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0

match_query = {'$match': {'scores.Hygiene': {'$eq': 0}}}

# 2. Groups the matches by Local Authority

group_query = {'$group': {'_id': "$LocalAuthorityName", 'count': { '$sum': 1 }}}

# 3. Sorts the matches from highest to lowest

sort_values = {'$sort': { 'count': -1 }}

# Put the pipeline together
pipeline = [match_query, group_query, sort_values]

# Run the pipeline through the aggregate method, cast the results as a list, and save the results to a variable
results4 = list(establishments.aggregate(pipeline))

# Print the number of documents in the result

print("Number of establishments in each Local Authority area have a hygiene score of 0 in result: ", len(results4))

# Print the first 10 results

pprint(results4[0:10])
# Out:
# Number of establishments in each Local Authority area have a hygiene score of 0 in result:  55
# [{'_id': 'Thanet', 'count': 1130},
#  {'_id': 'Greenwich', 'count': 882},
#  {'_id': 'Maidstone', 'count': 713},
#  {'_id': 'Newham', 'count': 711},
#  {'_id': 'Swale', 'count': 686},
#  {'_id': 'Chelmsford', 'count': 680},
#  {'_id': 'Medway', 'count': 672},
#  {'_id': 'Bexley', 'count': 607},
#  {'_id': 'Southend-On-Sea', 'count': 586},
#  {'_id': 'Tendring', 'count': 542}]

# %%
# Convert the result to a Pandas DataFrame

results4_df = pd.DataFrame(results4)

# Display the number of rows in the DataFrame
print("Rows in DataFrame: ", len(results4_df))

# Display the first 10 rows of the DataFrame
results4_df.head(10)
# Out:
# Rows in DataFrame:  55
#                _id  count
# 0           Thanet   1130
# 1        Greenwich    882
# 2        Maidstone    713
# 3           Newham    711
# 4            Swale    686
# 5       Chelmsford    680
# 6           Medway    672
# 7           Bexley    607
# 8  Southend-On-Sea    586
# 9         Tendring    542
